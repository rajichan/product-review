# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-305f3327-f0f0-47fa-8f04-cd09e1e95bc1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-305f3327-f0f0-47fa-8f04-cd09e1e95bc1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from wordcloud import WordCloud

# %%
data = pd.read_csv('/content/ap.zip')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3089 entries, 230499 to 47962
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  3089 non-null   object
#  1   Brand Name    3089 non-null   object
#  2   Price         3089 non-null   float64
#  3   Rating        3089 non-null   int64
#  4   Reviews       3089 non-null   object
#  5   Review Votes  3089 non-null   float64
#  6   Sentiment     3089 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 193.1+ KB

# %%
data.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
data.isnull().sum()
# Out:
# Product Name    0
# Brand Name      0
# Price           0
# Rating          0
# Reviews         0
# Review Votes    0
# Sentiment       0
# dtype: int64

# %%
print("Summary statistics of numerical features : \n", data.describe())

print("\nTotal number of reviews: ",len(data))
print("\nTotal number of brands: ", len(list(set(data['Brand Name']))))
print("\nTotal number of unique products: ", len(list(set(data['Product Name']))))

print("\nPercentage of reviews with neutral sentiment : {:.2f}%"\
      .format(data[data['Rating']==3]["Reviews"].count()/len(data)*100))
print("\nPercentage of reviews with positive sentiment : {:.2f}%"\
      .format(data[data['Rating']>3]["Reviews"].count()/len(data)*100))
print("\nPercentage of reviews with negative sentiment : {:.2f}%"\
      .format(data[data['Rating']<3]["Reviews"].count()/len(data)*100))
# Out:
# Summary statistics of numerical features :
#                 Price         Rating   Review Votes
# count  407907.000000  413840.000000  401544.000000
# mean      226.867155       3.819578       1.507237
# std       273.006259       1.548216       9.163853
# min         1.730000       1.000000       0.000000
# 25%        79.990000       3.000000       0.000000
# 50%       144.710000       5.000000       0.000000
# 75%       269.990000       5.000000       1.000000
# max      2598.000000       5.000000     645.000000
#
# Total number of reviews:  413840
#
# Total number of brands:  385
#
# Total number of unique products:  4410
#
# Percentage of reviews with neutral sentiment : 7.68%
#
# Percentage of reviews with positive sentiment : 68.86%
#
# Percentage of reviews with negative sentiment : 23.45%

# %%
plt.figure(figsize=(12,8))
data['Rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
brands = data["Brand Name"].value_counts()
plt.figure(figsize=(12,8))
brands[:20].plot(kind='bar')
plt.title("Number of Reviews for Top 20 Brands")
# Out:
# Text(0.5, 1.0, 'Number of Reviews for Top 20 Brands')

# %%
products = data["Product Name"].value_counts()
plt.figure(figsize=(12,8))
products[:50].plot(kind='bar')
plt.title("Number of Reviews for Top 50 Products")
# Out:
# Text(0.5, 1.0, 'Number of Reviews for Top 50 Products')

# %%
review_length = data["Reviews"].dropna().map(lambda x: len(x))
plt.figure(figsize=(12,8))
review_length.loc[review_length < 1500].hist()
plt.title("Distribution of Review Length")
plt.xlabel('Review length (Number of character)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
data = data.sample(frac=0.1, random_state=0)
data.dropna(inplace=True)
data = data[data['Rating'] != 3]
data['Sentiment'] = np.where(data['Rating'] > 3, 1, 0)
data.head()
# Out:
#                                              Product Name      Brand Name  \
# 230499  LG Nexus 5X Unlocked Smart Phone, 5.2" Quartz ...  LG Electronics
# 331895  Samsung Galaxy Note II N7100 16GB White-Unlock...         Samsung
# 287192  OtterBox Rugged Defender Series Case w/ Holste...        OtterBox
# 280029  OtterBox 77-29864 Defender Series Hybrid Case ...        OtterBox
# 53491   Apple iPhone 6 64GB Factory Unlocked GSM 4G LT...           Apple
#
#          Price  Rating                                            Reviews  \
# 230499  399.00       5  I love Nexus phones. My 2012 Nexus 4 still run...
# 331895  618.30       5  the best phone i ever knowCamera is not really...
# 287192   21.99       5        Came in the box and before it was promised!
# 280029    9.99       5  I love this, before I used to be really nervou...
# 53491   579.95       4  The only compliant is that the battery does no...
#
#         Review Votes  Sentiment
# 230499           0.0          1
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data['Reviews'], data['Sentiment'], \
                                                    test_size=0.1, random_state=0)

print('Load %d training examples and %d validation examples. \n' %(X_train.shape[0],X_test.shape[0]))
print('Show a review in the training set : \n', X_train.iloc[10])
# Out:
# Load 2780 training examples and 309 validation examples.
#
# Show a review in the training set :
#  the phone has locked up constantly since we received it. It has not worked properly.

# %%
def cleanText(raw_text, remove_stopwords=False, stemming=False, split_text=False, \
             ):
    '''
    Convert a raw review to a cleaned review
    '''
    text = BeautifulSoup(raw_text, 'lxml').get_text()
    letters_only = data.sub("[^a-zA-Z]", " ", text)
    words = letters_only.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]

    if stemming==True:
        stemmer = SnowballStemmer('english')
        words = [stemmer.stem(w) for w in words]

    if split_text==True:
        return (words)

    return( " ".join(words))

# %%
def modelEvaluation(predictions):
    '''
    Print model evaluation to predicted result
    '''
    print ("\nAccuracy on validation set: {:.4f}".format(accuracy_score(y_test, predictions)))
    print("\nAUC score : {:.4f}".format(roc_auc_score(y_test, predictions)))
    print("\nClassification report : \n", metrics.classification_report(y_test, predictions))
    print("\nConfusion Matrix : \n", metrics.confusion_matrix(y_test, predictions))

# %%
print(rf)
print(y_train)
# Out:
# RandomForestClassifier()
# 150674    1
# 253567    0
# 367397    1
# 172029    1
# 408059    0
#          ..
# 112268    1
# 163341    0
# 349199    1
# 18551     1
# 42727     0
# Name: Sentiment, Length: 2780, dtype: int64

# %%
from typing_extensions import dataclass_transform
def create_word_cloud(brand, sentiment):
    try:
        dataclass_transform_brand = data.loc[data['Brand Name'].isin([brand])]
        data_brand_sample = data_brand.sample(frac=0.1)
        word_cloud_collection = ''

        if sentiment == 1:
            data_reviews = data_brand_sample[data_brand_sample["Sentiment"]==1]["Reviews"]

        if sentiment == 0:
            data_reviews = data_brand_sample[data_brand_sample["Sentiment"]==0]["Reviews"]

        for val in data_reviews.str.lower():
            tokens = nltk.word_tokenize(val)
            tokens = [word for word in tokens if word not in stopwords.words('english')]
            for words in tokens:
                word_cloud_collection = word_cloud_collection + words + ' '

        wordcloud = WordCloud(max_font_size=50, width=500, height=300).generate(word_cloud_collection)
        plt.figure(figsize=(20,20))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()
    except:
        pass

# %%
create_word_cloud(brand='Apple', sentiment=1)

# %%
create_word_cloud(brand='Apple', sentiment=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from wordcloud import WordCloud
